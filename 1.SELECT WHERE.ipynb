# %%
# %load_ext sql
# %sql oracle://system:oracle@myoraxe11g:1521/xe

# %%
# %%sql
# alter user hr account unlock
# --hr계정 언락
# Out:
#  * oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# []

# %%
# %%sql
# alter user hr identified by hr
# Out:
#  * oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# []

# %%
# %sql oracle://hr:hr@myoraxe11g:1521/xe
--hr계정 접근

# %%
# %%sql
# SELECT * FROM employees
# --hr계정으로 접근해야 employees 접근가능
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(100, 'Steven', 'King', 'SKING', '515.123.4567', datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES', Decimal('24000'), None, None, 90),
#  (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', datetime.datetime(2005, 9, 21, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', datetime.datetime(2001, 1, 13, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', datetime.datetime(2006, 1, 3, 0, 0), 'IT_PROG', Decimal('9000'), None, 102, 60),
#  (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', datetime.datetime(2007, 5, 21, 0, 0), 'IT_PROG', Decimal('6000'), None, 103, 60),
#  (105, 'David', 'Austin', 'DAUSTIN', '590.423.4569', datetime.datetime(2005, 6, 25, 0, 0), 'IT_PROG', Decimal('4800'), None, 103, 60),
# ...

# %%
# %%sql
# SELECT first_name, last_name, salary
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', 'King', Decimal('24000')),
#  ('Neena', 'Kochhar', Decimal('17000')),
#  ('Lex', 'De Haan', Decimal('17000')),
#  ('Alexander', 'Hunold', Decimal('9000')),
#  ('Bruce', 'Ernst', Decimal('6000')),
#  ('David', 'Austin', Decimal('4800')),
#  ('Valli', 'Pataballa', Decimal('4800')),
#  ('Diana', 'Lorentz', Decimal('4200')),
#  ('Nancy', 'Greenberg', Decimal('12008')),
#  ('Daniel', 'Faviet', Decimal('9000')),
#  ('John', 'Chen', Decimal('8200')),
#  ('Ismael', 'Sciarra', Decimal('7700')),
#  ('Jose Manuel', 'Urman', Decimal('7800')),
#  ('Luis', 'Popp', Decimal('6900')),
#  ('Den', 'Raphaely', Decimal('11000')),
#  ('Alexander', 'Khoo', Decimal('3100')),
#  ('Shelli', 'Baida', Decimal('2900')),
#  ('Sigal', 'Tobias', Decimal('2800')),
#  ('Guy', 'Himuro', Decimal('2600')),
#  ('Karen', 'Colmenares', Decimal('2500')),
#  ('Matthew', 'Weiss', Decimal('8000')),
# ...

# %%
# %%sql
# SELECT first_name, last_name, salary, salary + salary*0.5
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', 'King', Decimal('24000'), 36000),
#  ('Neena', 'Kochhar', Decimal('17000'), 25500),
#  ('Lex', 'De Haan', Decimal('17000'), 25500),
#  ('Alexander', 'Hunold', Decimal('9000'), 13500),
#  ('Bruce', 'Ernst', Decimal('6000'), 9000),
#  ('David', 'Austin', Decimal('4800'), 7200),
#  ('Valli', 'Pataballa', Decimal('4800'), 7200),
#  ('Diana', 'Lorentz', Decimal('4200'), 6300),
#  ('Nancy', 'Greenberg', Decimal('12008'), 18012),
#  ('Daniel', 'Faviet', Decimal('9000'), 13500),
#  ('John', 'Chen', Decimal('8200'), 12300),
#  ('Ismael', 'Sciarra', Decimal('7700'), 11550),
#  ('Jose Manuel', 'Urman', Decimal('7800'), 11700),
#  ('Luis', 'Popp', Decimal('6900'), 10350),
#  ('Den', 'Raphaely', Decimal('11000'), 16500),
#  ('Alexander', 'Khoo', Decimal('3100'), 4650),
#  ('Shelli', 'Baida', Decimal('2900'), 4350),
#  ('Sigal', 'Tobias', Decimal('2800'), 4200),
# ...

# %%
# %%sql
# SELECT first_name, department_id, commission_pct
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', 90, None),
#  ('Neena', 90, None),
#  ('Lex', 90, None),
#  ('Alexander', 60, None),
#  ('Bruce', 60, None),
#  ('David', 60, None),
#  ('Valli', 60, None),
#  ('Diana', 60, None),
#  ('Nancy', 100, None),
#  ('Daniel', 100, None),
#  ('John', 100, None),
#  ('Ismael', 100, None),
#  ('Jose Manuel', 100, None),
#  ('Luis', 100, None),
#  ('Den', 30, None),
#  ('Alexander', 30, None),
#  ('Shelli', 30, None),
#  ('Sigal', 30, None),
#  ('Guy', 30, None),
#  ('Karen', 30, None),
#  ('Matthew', 50, None),
#  ('Adam', 50, None),
#  ('Payam', 50, None),
#  ('Shanta', 50, None),
#  ('Kevin', 50, None),
#  ('Julia', 50, None),
#  ('Irene', 50, None),
#  ('James', 50, None),
#  ('Steven', 50, None),
#  ('Laura', 50, None),
#  ('Mozhe', 50, None),
#  ('James', 50, None),
#  ('TJ', 50, None),
#  ('Jason', 50, None),
#  ('Michael', 50, None),
#  ('Ki', 50, None),
# ...

# %%
# %%sql
# SELECT first_name "Employee Name",
#     salary*12 "Annual Salary"
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', 288000),
#  ('Neena', 204000),
#  ('Lex', 204000),
#  ('Alexander', 108000),
#  ('Bruce', 72000),
#  ('David', 57600),
#  ('Valli', 57600),
#  ('Diana', 50400),
#  ('Nancy', 144096),
#  ('Daniel', 108000),
#  ('John', 98400),
#  ('Ismael', 92400),
#  ('Jose Manuel', 93600),
#  ('Luis', 82800),
#  ('Den', 132000),
#  ('Alexander', 37200),
#  ('Shelli', 34800),
#  ('Sigal', 33600),
#  ('Guy', 31200),
#  ('Karen', 30000),
#  ('Matthew', 96000),
#  ('Adam', 98400),
#  ('Payam', 94800),
#  ('Shanta', 78000),
#  ('Kevin', 69600),
#  ('Julia', 38400),
#  ('Irene', 32400),
#  ('James', 28800),
#  ('Steven', 26400),
#  ('Laura', 39600),
#  ('Mozhe', 33600),
#  ('James', 30000),
#  ('TJ', 25200),
#  ('Jason', 39600),
#  ('Michael', 34800),
#  ('Ki', 28800),
#  ('Hazel', 26400),
#  ('Renske', 43200),
#  ('Stephen', 38400),
#  ('John', 32400),
#  ('Joshua', 30000),
# ...

# %%
# %%sql
# SELECT first_name || ' ' || last_name AS "Full Name"
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Ellen Abel',),
#  ('Sundar Ande',),
#  ('Mozhe Atkinson',),
#  ('David Austin',),
#  ('Hermann Baer',),
#  ('Shelli Baida',),
#  ('Amit Banda',),
#  ('Elizabeth Bates',),
#  ('Sarah Bell',),
#  ('David Bernstein',),
#  ('Laura Bissot',),
#  ('Harrison Bloom',),
#  ('Alexis Bull',),
#  ('Anthony Cabrio',),
#  ('Gerald Cambrault',),
#  ('Nanette Cambrault',),
#  ('John Chen',),
#  ('Kelly Chung',),
#  ('Karen Colmenares',),
#  ('Curtis Davies',),
#  ('Lex De Haan',),
#  ('Julia Dellinger',),
#  ('Jennifer Dilly',),
#  ('Louise Doran',),
#  ('Bruce Ernst',),
#  ('Alberto Errazuriz',),
#  ('Britney Everett',),
#  ('Daniel Faviet',),
#  ('Pat Fay',),
#  ('Kevin Feeney',),
#  ('Jean Fleaur',),
#  ('Tayler Fox',),
#  ('Adam Fripp',),
#  ('Timothy Gates',),
#  ('Ki Gee',),
#  ('Girard Geoni',),
#  ('William Gietz',),
#  ('Douglas Grant',),
#  ('Kimberely Grant',),
# ...

# %%
# %%sql
# SELECT first_name || ' Mr'
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Ellen Mr',),
#  ('Sundar Mr',),
#  ('Mozhe Mr',),
#  ('David Mr',),
#  ('Hermann Mr',),
#  ('Shelli Mr',),
#  ('Amit Mr',),
#  ('Elizabeth Mr',),
#  ('Sarah Mr',),
#  ('David Mr',),
#  ('Laura Mr',),
#  ('Harrison Mr',),
#  ('Alexis Mr',),
#  ('Anthony Mr',),
#  ('Gerald Mr',),
#  ('Nanette Mr',),
#  ('John Mr',),
#  ('Kelly Mr',),
#  ('Karen Mr',),
#  ('Curtis Mr',),
#  ('Lex Mr',),
#  ('Julia Mr',),
#  ('Jennifer Mr',),
#  ('Louise Mr',),
#  ('Bruce Mr',),
#  ('Alberto Mr',),
#  ('Britney Mr',),
#  ('Daniel Mr',),
#  ('Pat Mr',),
#  ('Kevin Mr',),
#  ('Jean Mr',),
#  ('Tayler Mr',),
#  ('Adam Mr',),
#  ('Timothy Mr',),
#  ('Ki Mr',),
#  ('Girard Mr',),
#  ('William Mr',),
#  ('Douglas Mr',),
#  ('Kimberely Mr',),
#  ('Nancy Mr',),
#  ('Danielle Mr',),
#  ('Peter Mr',),
#  ('Michael Mr',),
#  ('Shelley Mr',),
#  ('Guy Mr',),
#  ('Alexander Mr',),
#  ('Alyssa Mr',),
# ...

# %%
# %%sql
# SELECT * FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(100, 'Steven', 'King', 'SKING', '515.123.4567', datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES', Decimal('24000'), None, None, 90),
#  (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', datetime.datetime(2005, 9, 21, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', datetime.datetime(2001, 1, 13, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', datetime.datetime(2006, 1, 3, 0, 0), 'IT_PROG', Decimal('9000'), None, 102, 60),
#  (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', datetime.datetime(2007, 5, 21, 0, 0), 'IT_PROG', Decimal('6000'), None, 103, 60),
#  (105, 'David', 'Austin', 'DAUSTIN', '590.423.4569', datetime.datetime(2005, 6, 25, 0, 0), 'IT_PROG', Decimal('4800'), None, 103, 60),
# ...

# %%
# %%sql
# SELECT DISTINCT department_id
# from employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(100,),
#  (30,),
#  (None,),
#  (90,),
#  (20,),
#  (70,),
#  (110,),
#  (50,),
#  (80,),
#  (40,),
#  (60,),
#  (10,)]

# %%
# %%sql
# SELECT first_name, job_id, department_id
# FROM employees
# Where job_id = 'IT_PROG'
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Alexander', 'IT_PROG', 60),
#  ('Bruce', 'IT_PROG', 60),
#  ('David', 'IT_PROG', 60),
#  ('Valli', 'IT_PROG', 60),
#  ('Diana', 'IT_PROG', 60)]

# %%
# %%sql
# SELECT first_name, last_name, hire_date
# FROM employees
# WHERE last_name = 'King'
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Janette', 'King', datetime.datetime(2004, 1, 30, 0, 0)),
#  ('Steven', 'King', datetime.datetime(2003, 6, 17, 0, 0))]

# %%
# %%sql
# SELECT first_name, salary, hire_date, job_id
# FROM employees
# WHERE salary >= 15000
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', Decimal('24000'), datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES'),
#  ('Neena', Decimal('17000'), datetime.datetime(2005, 9, 21, 0, 0), 'AD_VP'),
#  ('Lex', Decimal('17000'), datetime.datetime(2001, 1, 13, 0, 0), 'AD_VP')]

# %%
# %%sql
# SELECT first_name, salary, hire_date
# FROM employees
# WHERE hire_date='30/01/2004'
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# DatabaseErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# DatabaseError: ORA-01843: not a valid month
#
# The above exception was the direct cause of the following exception:
#
# DatabaseErrorTraceback (most recent call last)
# <ipython-input-12-ff4f1f6c5f65> in <module>
# ...

# %%
# %%sql
# SELECT first_name, salary, hire_date, job_id
# FROM employees
# WHERE first_name = 'Steven'
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', Decimal('24000'), datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES'),
#  ('Steven', Decimal('2200'), datetime.datetime(2008, 3, 8, 0, 0), 'ST_CLERK')]

# %%
# %%sql
# SELECT first_name, salary
# FROM employees
# --WHERE salary BETWEEN 10000 AND 12000 --신방법, 구버전에선 미작동
# WHERE salary>10000 AND salary < 12000 --구방범
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Den', Decimal('11000')),
#  ('Gerald', Decimal('11000')),
#  ('Eleni', Decimal('10500')),
#  ('Clara', Decimal('10500')),
#  ('Lisa', Decimal('11500')),
#  ('Ellen', Decimal('11000'))]

# %%
# %%sql
# SELECT employee_id, first_name, salary, manager_id
# FROM employees
# WHERE manager_id IN (101,102,103)
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(108, 'Nancy', Decimal('12008'), 101),
#  (200, 'Jennifer', Decimal('4400'), 101),
#  (203, 'Susan', Decimal('6500'), 101),
#  (204, 'Hermann', Decimal('10000'), 101),
#  (205, 'Shelley', Decimal('12008'), 101),
#  (103, 'Alexander', Decimal('9000'), 102),
#  (104, 'Bruce', Decimal('6000'), 103),
#  (105, 'David', Decimal('4800'), 103),
#  (106, 'Valli', Decimal('4800'), 103),
#  (107, 'Diana', Decimal('4200'), 103)]

# %%
# %%sql
# SELECT employee_id, first_name, salary, manager_id
# FROM employees
# WHERE job_id IN ('IT_PROG')
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(103, 'Alexander', Decimal('9000'), 102),
#  (104, 'Bruce', Decimal('6000'), 103),
#  (105, 'David', Decimal('4800'), 103),
#  (106, 'Valli', Decimal('4800'), 103),
#  (107, 'Diana', Decimal('4200'), 103)]

# %%
# %%sql
# SELECT first_name, last_name, job_id, department_id
# FROM employees
# WHERE job_id LIKE 'IT%' --LIke문은 비슷한 것을 찾아줌, _언더바는 칸까지 지정
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Alexander', 'Hunold', 'IT_PROG', 60),
#  ('Bruce', 'Ernst', 'IT_PROG', 60),
#  ('David', 'Austin', 'IT_PROG', 60),
#  ('Valli', 'Pataballa', 'IT_PROG', 60),
#  ('Diana', 'Lorentz', 'IT_PROG', 60)]

# %%
# %%sql
# SELECT first_name, manager_id
# FROM employees
# WHERE manager_id IS NULL
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', None)]

# %%
# %%sql
# SELECT first_name, manager_id
# FROM employees
# WHERE manager_id IS NOT NULL
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Ellen', 149),
#  ('Sundar', 147),
#  ('Mozhe', 121),
#  ('David', 103),
#  ('Hermann', 101),
#  ('Shelli', 114),
#  ('Amit', 147),
#  ('Elizabeth', 148),
#  ('Sarah', 123),
#  ('David', 145),
#  ('Laura', 121),
#  ('Harrison', 148),
#  ('Alexis', 121),
#  ('Anthony', 121),
#  ('Gerald', 100),
#  ('Nanette', 145),
#  ('John', 108),
#  ('Kelly', 122),
#  ('Karen', 114),
#  ('Curtis', 124),
#  ('Lex', 100),
#  ('Julia', 121),
#  ('Jennifer', 122),
#  ('Louise', 146),
#  ('Bruce', 103),
#  ('Alberto', 100),
#  ('Britney', 123),
#  ('Daniel', 108),
#  ('Pat', 201),
#  ('Kevin', 124),
#  ('Jean', 120),
#  ('Tayler', 148),
#  ('Adam', 100),
#  ('Timothy', 122),
#  ('Ki', 122),
#  ('Girard', 120),
#  ('William', 205),
#  ('Douglas', 124),
#  ('Kimberely', 149),
#  ('Nancy', 101),
#  ('Danielle', 147),
#  ('Peter', 145),
#  ('Michael', 100),
#  ('Shelley', 101),
#  ('Guy', 114),
# ...

# %%
# %%sql
# SELECT first_name, job_id, salary
# FROM employees
# WHERE job_id = 'IT_PROG' OR job_id = 'FI_MGR' AND salary >= 6000
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Alexander', 'IT_PROG', Decimal('9000')),
#  ('Bruce', 'IT_PROG', Decimal('6000')),
#  ('David', 'IT_PROG', Decimal('4800')),
#  ('Valli', 'IT_PROG', Decimal('4800')),
#  ('Diana', 'IT_PROG', Decimal('4200')),
#  ('Nancy', 'FI_MGR', Decimal('12008'))]
