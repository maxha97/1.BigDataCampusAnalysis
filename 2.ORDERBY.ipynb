# %%
# %load_ext sql
# %sql oracle://system:oracle@myoraxe11g:1521/xe

# %%
# %sql oracle://hr:hr@myoraxe11g:1521/xe

# %%
# %%sql
# SELECT first_name, hire_date
# FROM employees
# ORDER BY hire_date DESC
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Sundita', datetime.datetime(2008, 4, 21, 0, 0)),
#  ('Amit', datetime.datetime(2008, 4, 21, 0, 0)),
#  ('Sundar', datetime.datetime(2008, 3, 24, 0, 0)),
#  ('Steven', datetime.datetime(2008, 3, 8, 0, 0)),
#  ('David', datetime.datetime(2008, 2, 23, 0, 0)),
#  ('Hazel', datetime.datetime(2008, 2, 6, 0, 0)),
#  ('Girard', datetime.datetime(2008, 2, 3, 0, 0)),
#  ('Eleni', datetime.datetime(2008, 1, 29, 0, 0)),
#  ('Mattea', datetime.datetime(2008, 1, 24, 0, 0)),
#  ('Douglas', datetime.datetime(2008, 1, 13, 0, 0)),
#  ('Charles', datetime.datetime(2008, 1, 4, 0, 0)),
#  ('Randall', datetime.datetime(2007, 12, 19, 0, 0)),
#  ('Ki', datetime.datetime(2007, 12, 12, 0, 0)),
#  ('Luis', datetime.datetime(2007, 12, 7, 0, 0)),
#  ('Oliver', datetime.datetime(2007, 11, 23, 0, 0)),
#  ('Kevin', datetime.datetime(2007, 11, 16, 0, 0)),
#  ('Gerald', datetime.datetime(2007, 10, 15, 0, 0)),
# ...

# %%
# %%sql
# SELECT first_name, hire_date
# FROM employees
# ORDER BY 2 DESC --내림차순
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Sundita', datetime.datetime(2008, 4, 21, 0, 0)),
#  ('Amit', datetime.datetime(2008, 4, 21, 0, 0)),
#  ('Sundar', datetime.datetime(2008, 3, 24, 0, 0)),
#  ('Steven', datetime.datetime(2008, 3, 8, 0, 0)),
#  ('David', datetime.datetime(2008, 2, 23, 0, 0)),
#  ('Hazel', datetime.datetime(2008, 2, 6, 0, 0)),
#  ('Girard', datetime.datetime(2008, 2, 3, 0, 0)),
#  ('Eleni', datetime.datetime(2008, 1, 29, 0, 0)),
#  ('Mattea', datetime.datetime(2008, 1, 24, 0, 0)),
#  ('Douglas', datetime.datetime(2008, 1, 13, 0, 0)),
#  ('Charles', datetime.datetime(2008, 1, 4, 0, 0)),
#  ('Randall', datetime.datetime(2007, 12, 19, 0, 0)),
#  ('Ki', datetime.datetime(2007, 12, 12, 0, 0)),
#  ('Luis', datetime.datetime(2007, 12, 7, 0, 0)),
#  ('Oliver', datetime.datetime(2007, 11, 23, 0, 0)),
#  ('Kevin', datetime.datetime(2007, 11, 16, 0, 0)),
#  ('Gerald', datetime.datetime(2007, 10, 15, 0, 0)),
# ...

# %%
# %%sql
# SELECT first_name, hire_date
# FROM employees
# ORDER BY hire_date ASC --오름차순
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Lex', datetime.datetime(2001, 1, 13, 0, 0)),
#  ('William', datetime.datetime(2002, 6, 7, 0, 0)),
#  ('Hermann', datetime.datetime(2002, 6, 7, 0, 0)),
#  ('Susan', datetime.datetime(2002, 6, 7, 0, 0)),
#  ('Shelley', datetime.datetime(2002, 6, 7, 0, 0)),
#  ('Daniel', datetime.datetime(2002, 8, 16, 0, 0)),
#  ('Nancy', datetime.datetime(2002, 8, 17, 0, 0)),
#  ('Den', datetime.datetime(2002, 12, 7, 0, 0)),
#  ('Payam', datetime.datetime(2003, 5, 1, 0, 0)),
#  ('Alexander', datetime.datetime(2003, 5, 18, 0, 0)),
#  ('Steven', datetime.datetime(2003, 6, 17, 0, 0)),
#  ('Renske', datetime.datetime(2003, 7, 14, 0, 0)),
#  ('Jennifer', datetime.datetime(2003, 9, 17, 0, 0)),
#  ('Trenna', datetime.datetime(2003, 10, 17, 0, 0)),
#  ('Nandita', datetime.datetime(2004, 1, 27, 0, 0)),
#  ('Janette', datetime.datetime(2004, 1, 30, 0, 0)),
#  ('Sarah', datetime.datetime(2004, 2, 4, 0, 0)),
# ...

# %%
# %%sql
# SELECT department_id, salary, first_name, hire_date
# FROM employees
# ORDER BY department_id, salary DESC --Department id 작은 것부터 순서대로(오름차순으로) 나열, 그 안에서 salary 기준으로 내림차순으로 정리
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
#    oracle://system:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(10, Decimal('4400'), 'Jennifer', datetime.datetime(2003, 9, 17, 0, 0)),
#  (20, Decimal('13000'), 'Michael', datetime.datetime(2004, 2, 17, 0, 0)),
#  (20, Decimal('6000'), 'Pat', datetime.datetime(2005, 8, 17, 0, 0)),
#  (30, Decimal('11000'), 'Den', datetime.datetime(2002, 12, 7, 0, 0)),
#  (30, Decimal('3100'), 'Alexander', datetime.datetime(2003, 5, 18, 0, 0)),
#  (30, Decimal('2900'), 'Shelli', datetime.datetime(2005, 12, 24, 0, 0)),
#  (30, Decimal('2800'), 'Sigal', datetime.datetime(2005, 7, 24, 0, 0)),
#  (30, Decimal('2600'), 'Guy', datetime.datetime(2006, 11, 15, 0, 0)),
#  (30, Decimal('2500'), 'Karen', datetime.datetime(2007, 8, 10, 0, 0)),
#  (40, Decimal('6500'), 'Susan', datetime.datetime(2002, 6, 7, 0, 0)),
#  (50, Decimal('8200'), 'Adam', datetime.datetime(2005, 4, 10, 0, 0)),
#  (50, Decimal('8000'), 'Matthew', datetime.datetime(2004, 7, 18, 0, 0)),
# ...
