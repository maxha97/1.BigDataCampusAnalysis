# %%
# %reload_ext sql
# %sql oracle://hr:hr@myoraxe11g:1521/xe

# %%
# %%sql
# SELECT first_name, salary
# FROM employees
# WHERE salary > (SELECT salary FROM employees WHERE first_name = 'Nancy')
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', Decimal('24000')),
#  ('Neena', Decimal('17000')),
#  ('Lex', Decimal('17000')),
#  ('John', Decimal('14000')),
#  ('Karen', Decimal('13500')),
#  ('Michael', Decimal('13000'))]

# %%
# %%sql
# SELECT first_name, salary
# FROM employees a
# WHERE salary > (SELECT AVG(salary)
#                FROM employees b
#                WHERE b.department_id = a.department_id)
#
# --상호참조 쿼리의 경우 안쓰는 것을 권장
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Steven', Decimal('24000')),
#  ('Alexander', Decimal('9000')),
#  ('Bruce', Decimal('6000')),
#  ('Nancy', Decimal('12008')),
#  ('Daniel', Decimal('9000')),
#  ('Den', Decimal('11000')),
#  ('Matthew', Decimal('8000')),
#  ('Adam', Decimal('8200')),
#  ('Payam', Decimal('7900')),
#  ('Shanta', Decimal('6500')),
#  ('Kevin', Decimal('5800')),
#  ('Renske', Decimal('3600')),
#  ('Trenna', Decimal('3500')),
#  ('John', Decimal('14000')),
#  ('Karen', Decimal('13500')),
#  ('Alberto', Decimal('12000')),
#  ('Gerald', Decimal('11000')),
#  ('Eleni', Decimal('10500')),
#  ('Peter', Decimal('10000')),
#  ('David', Decimal('9500')),
#  ('Peter', Decimal('9000')),
#  ('Janette', Decimal('10000')),
#  ('Patrick', Decimal('9500')),
#  ('Allan', Decimal('9000')),
#  ('Clara', Decimal('10500')),
#  ('Danielle', Decimal('9500')),
#  ('Lisa', Decimal('11500')),
#  ('Harrison', Decimal('10000')),
#  ('Tayler', Decimal('9600')),
# ...

# %%
# %%sql
# SELECT first_name, (SELECT department_name
#                    FROM departments d
#                    WHERE d.department_id = e.department_id) as department_name
# FROM employees e
# ORDER BY first_name
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [('Adam', 'Shipping'),
#  ('Alana', 'Shipping'),
#  ('Alberto', 'Sales'),
#  ('Alexander', 'IT'),
#  ('Alexander', 'Purchasing'),
#  ('Alexis', 'Shipping'),
#  ('Allan', 'Sales'),
#  ('Alyssa', 'Sales'),
#  ('Amit', 'Sales'),
#  ('Anthony', 'Shipping'),
#  ('Britney', 'Shipping'),
#  ('Bruce', 'IT'),
#  ('Charles', 'Sales'),
#  ('Christopher', 'Sales'),
#  ('Clara', 'Sales'),
#  ('Curtis', 'Shipping'),
#  ('Daniel', 'Finance'),
#  ('Danielle', 'Sales'),
#  ('David', 'IT'),
#  ('David', 'Sales'),
#  ('David', 'Sales'),
#  ('Den', 'Purchasing'),
#  ('Diana', 'IT'),
#  ('Donald', 'Shipping'),
#  ('Douglas', 'Shipping'),
#  ('Eleni', 'Sales'),
#  ('Elizabeth', 'Sales'),
#  ('Ellen', 'Sales'),
#  ('Gerald', 'Sales'),
#  ('Girard', 'Shipping'),
#  ('Guy', 'Purchasing'),
#  ('Harrison', 'Sales'),
#  ('Hazel', 'Shipping'),
#  ('Hermann', 'Public Relations'),
#  ('Irene', 'Shipping'),
#  ('Ismael', 'Finance'),
#  ('Jack', 'Sales'),
# ...

# %%
# %%sql
# SELECT row_number, first_name, salary
# FROM (SELECT first_name, salary,
#      row_number() OVER (ORDER BY salary DESC) AS row_number
#      FROM employees
#      ORDER BY salary DESC)
# WHERE row_number BETWEEN  1 AND 10
# --인라인뷰(테이블 대신 서브쿼리가 오는 것)
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(1, 'Steven', Decimal('24000')),
#  (2, 'Neena', Decimal('17000')),
#  (3, 'Lex', Decimal('17000')),
#  (4, 'John', Decimal('14000')),
#  (5, 'Karen', Decimal('13500')),
#  (6, 'Michael', Decimal('13000')),
#  (7, 'Nancy', Decimal('12008')),
#  (8, 'Shelley', Decimal('12008')),
#  (9, 'Alberto', Decimal('12000')),
#  (10, 'Lisa', Decimal('11500'))]

# %%
# %%sql
# SELECT rnum, first_name, salary
# FROM (SELECT first_name, salary, rownum AS rnum
#      FROM (SELECT first_name, salary
#           FROM employees
#           ORDER BY salary DESC))
# WHERE rnum BETWEEN 11 and 20
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(11, 'Den', Decimal('11000')),
#  (12, 'Gerald', Decimal('11000')),
#  (13, 'Ellen', Decimal('11000')),
#  (14, 'Eleni', Decimal('10500')),
#  (15, 'Clara', Decimal('10500')),
#  (16, 'Janette', Decimal('10000')),
#  (17, 'Peter', Decimal('10000')),
#  (18, 'Hermann', Decimal('10000')),
#  (19, 'Harrison', Decimal('10000')),
#  (20, 'Tayler', Decimal('9600'))]

# %%
# %%sql
# SELECT *
# FROM employees
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(100, 'Steven', 'King', 'SKING', '515.123.4567', datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES', Decimal('24000'), None, None, 90),
#  (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', datetime.datetime(2005, 9, 21, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', datetime.datetime(2001, 1, 13, 0, 0), 'AD_VP', Decimal('17000'), None, 100, 90),
#  (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', datetime.datetime(2006, 1, 3, 0, 0), 'IT_PROG', Decimal('9000'), None, 102, 60),
#  (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', datetime.datetime(2007, 5, 21, 0, 0), 'IT_PROG', Decimal('6000'), None, 103, 60),
#  (105, 'David', 'Austin', 'DAUSTIN', '590.423.4569', datetime.datetime(2005, 6, 25, 0, 0), 'IT_PROG', Decimal('4800'), None, 103, 60),
# ...

# %%
# %%sql
# SELECT employee_id,
# LPAD(' ', 3*(LEVEL-1)) || first_name || ' ' || last_name,
# LEVEL
# FROM employees
# START WITH manager_id IS NULL --최상위 노드
# CONNECT BY employee_id = manager_id --부모노드와 자식노드 연결
#
# --계층형 쿼리, 여기선 직원보다 매니저가 상위
# --employee_id 에서의 manager_id로 상위직급 employee_id로 연결되는 구조
# --매니저가 level 1, 직원이 level 2
# Out:
#  * oracle://hr:***@myoraxe11g:1521/xe
# 0 rows affected.
# [(100, 'Steven King', 1)]
